# %%
# !pip install -U PyYAML
import yaml
# !pip uninstall twint
# !pip install twint
# !pip install --user --upgrade
import twint
import nest_asyncio
import pandas as pd
# Out:
# ...
# Found existing installation: twint 2.1.20
# Uninstalling twint-2.1.20:
#   Would remove:
#     /usr/local/bin/twint
#     /usr/local/lib/python3.7/dist-packages/twint-2.1.20.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/twint/*
# Proceed (y/n)? y
#   Successfully uninstalled twint-2.1.20
# ...
#   Using cached twint-2.1.20-py3-none-any.whl
# ...
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
with open('config.yaml') as File:
    _dict = yaml.load(File, Loader=yaml.FullLoader)

for i in _dict:
    nest_asyncio.apply()

    c = twint.Config()
    c.Search = _dict[i]['Search']
    c.Limit = _dict[i]['Limit']
    c.Store_csv = _dict[i]['Store_csv']
    c.Output = _dict[i]['Output']
    c.Since = _dict[i]['Since']
    c.Lang = _dict[i]['Lang']
    # c.Geo = _dict[i]['Geo']
    twint.run.Search(c)
# Out:
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 1.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 8.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 27.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 64.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 125.0 secs

# %%
for i in _dict:
    nest_asyncio.apply()

    c = twint.Config()
    c.Search = _dict[i]['Search']
    c.Limit = _dict[i]['Limit']
    c.Store_csv = _dict[i]['Store_csv']
    c.Output = _dict[i]['Output']
    c.Since = _dict[i]['Since']
    c.Lang = _dict[i]['Lang']
    # c.Geo = _dict[i]['Geo']
    twint.run.Search(c)

# %%
ls

# %%
ls
# Out:
# config.yaml*  Final_scrapper.ipynb*  Out.csv*
