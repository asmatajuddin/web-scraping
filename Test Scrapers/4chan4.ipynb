# %%
import pandas as pd

# !pip install basc-py4chan
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting basc-py4chan
#   Downloading BASC-py4chan-0.6.6.tar.gz (11 kB)
# Requirement already satisfied: requests>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from basc-py4chan) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->basc-py4chan) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->basc-py4chan) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->basc-py4chan) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=1.0.0->basc-py4chan) (3.0.4)
# Building wheels for collected packages: basc-py4chan
#   Building wheel for basc-py4chan (setup.py) ... done
#   Created wheel for basc-py4chan: filename=BASC_py4chan-0.6.6-py3-none-any.whl size=14132 sha256=5c2303a0690ce253f24b77a2f8fbd6cadb99128f5835735d78a6a9cfa40cfea8
#   Stored in directory: /root/.cache/pip/wheels/95/66/e9/a5e56cea0f8d6213f03646c6559c78df945d520267acfddbfd
# Successfully built basc-py4chan
# Installing collected packages: basc-py4chan
# Successfully installed basc-py4chan-0.6.6

# %%
import basc_py4chan

# %%
b = basc_py4chan.Board('g')
thread = b.get_thread(87096906)

print(thread)

for file in thread.files():
    print(file)

# In a while...
print("I fetched", thread.update(), "new replies.")
# Out:
# <Thread /g/87096906, 24 replies>
# http://i.4cdn.org/g/1653573497348.jpg
# http://i.4cdn.org/g/1653573830087.png
# http://i.4cdn.org/g/1653575190968.jpg
# http://i.4cdn.org/g/1653578276926.webm
# http://i.4cdn.org/g/1653579959857.jpg
# http://i.4cdn.org/g/1653580378014.jpg
# http://i.4cdn.org/g/1653580684376.jpg
# I fetched 0 new replies.

# %%
import basc_py4chan

class URL (basc_py4chan.URL):
    # see BASC-py4chan's `url.py` for an example of how to set up
    # the URLs.
    def __init__(self, https=False):
        # Your API URL Subdomains
        DOMAIN = { }

        # Your API URL Templates
        TEMPLATE = { }

        # Your API Listings
        LISTING = { }

        # combine all dictionaries into self.URL dictionary
        self.URL = TEMPLATE
        self.URL.update({'domain': DOMAIN})
        self.URL.update({'listing': LISTING})

class Board(basc_py4chan.Board):
    # add your own overrides here, or leave it alone
    pass

class Thread(basc_py4chan.Threads):
    # add your own overrides here, or leave it alone
    pass

class Post(basc_py4chan.Post):
    # add your own overrides here, or leave it alone
    pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ef3140626c34> in <module>()
#       1 import basc_py4chan
#       2
# ----> 3 class URL (basc_py4chan.URL):
#       4     # see BASC-py4chan's `url.py` for an example of how to set up
#       5     # the URLs.
#
# AttributeError: module 'basc_py4chan' has no attribute 'URL'
