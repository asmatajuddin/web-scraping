# %% [markdown]
# https://twitter.com/search-advanced
#
# go here and enter your search parameters
#
# copy and paste what it enters in your twitter search bar in to the quotes below for the query argument
#
# then limit is just the limit. I would recommend starting small then making it larger
#
# after you enter your seach term and your limit of tweets you can run all under the runtime

# %%
query = "(sba OR SBAList OR protest) until:2022-05-18"

limit = 5000

# %% [markdown]
# ###Code under here

# %%
import os
import pandas as pd
# !pip install -q snscrape
from datetime import date
import snscrape.modules.twitter as sntwitter

tweets = []

for tweet in sntwitter.TwitterSearchScraper(query).get_items():

    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content])

df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet'])

# to save to csv
# df.to_csv('tweets.csv')

# %% [markdown]
# ###Data is here

# %%
df
# Out:
#                           Date           User  \
# 0    2022-05-17 20:53:05+00:00     rossco1304
# 1    2022-05-17 20:53:03+00:00    AlshykhhSba
# 2    2022-05-17 20:52:59+00:00    Blunami2020
# 3    2022-05-17 20:52:59+00:00    AlshykhhSba
# 4    2022-05-17 20:52:59+00:00    radgirlgunk
# ...                        ...            ...
# 4995 2022-05-17 15:52:17+00:00   LisaGrande13
# 4996 2022-05-17 15:52:13+00:00  LondonWC2B5ND
# 4997 2022-05-17 15:52:04+00:00      ResandraM
# 4998 2022-05-17 15:52:02+00:00  GizemZiyagill
# 4999 2022-05-17 15:51:57+00:00          uspcn
#
#                                                   Tweet
# 0     @jaketapper Banning the right to protest?\nI t...
# 1     @vFLSxnbPbwogrdV @alhuda2022 @manar__313 @YgsP...
# 2     @jaketapper What if it’s a “pro-stand your gro...
# 3     باراك رافيد، واللا العبري: وزير الحرب غانتس سي...
# 4     Would you protest against yourself? https://t....
# ...                                                 ...
# ...

# %%
df.to_csv('tweets.csv')

# %%
df.dtypes

# %%
# !pip install boto3
import boto3

# %%
s3 = boto3.client('s3')

# %%
s3 = boto3.resource(
    service_name='s3',
    region_name='us-east-2',
    aws_access_key_id='AKIAUOZ7CQ6YY7WQJRX3',
    aws_secret_access_key='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'
)

# %%
Print out bucket names
for bucket in s3.buckets.all():
    print(bucket.name)

# %%
# !pip install s3fs

# %%
s3.Bucket('datascience2').upload_file(Filename='tweets.csv', Key='Tweets.csv')
