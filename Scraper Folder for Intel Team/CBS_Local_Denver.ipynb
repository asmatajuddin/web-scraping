# %% [markdown]
# ### Scraping Denver CBS local news
# The scraper collects data from local news, health and politics section of Denver CBS local news.

# %%
import requests                # to request the webpage
from bs4 import BeautifulSoup  # to make soup and pull data out of HTML
import urllib.robotparser      # to check the legitimacy to scrap the web
import json                    # to save the output as json file
import pandas as pd            # to  see saved data as dataframe 
from datetime import datetime  # to get the current datetime
#import IPython                 # to display the webpage

# %% [markdown]
# ### Check permission to scrape the webpage

# %%
robotpars = urllib.robotparser.RobotFileParser()  #instantiate the RobotFileParser

#set the robots.txt url of cbs local news 
robotpars.set_url("https://denver.cbslocal.com/category/news/robots.txt")
robotpars.read() # Reads the robots.txt 

# to check if useragent can fetch the url, true means fetching is possible. 
print("Can we fetch cbslocal website?", \
      robotpars.can_fetch("*", "https://denver.cbslocal.com/category/news/"))
# Out:
# Can we fetch cbslocal website? True

# %%
def getSoup(url):
    """make a soup for a webpage given its url""" 

    # request the webpage and get the text
    pagetext= requests.get(url).text
    #make a soup and use html parser for the content of the web page 
    soup= BeautifulSoup(pagetext, "html.parser")
    return soup

# %%
def getCategoryLink(soup):
    """Returns a list containing the links of news categories
       soup: is the soup of a webpage from which the links of the categories extracted.
     """
    sec_list= [] # placeholder for section link
    
    cbsn_link= soup.find("section", attrs={"class":"blogroll-item template-catalog"}).h4.a["href"] # get the link for cbs-denver- local news section 
    sec_list.append(cbsn_link)
    
    sections= soup.find_all("section", attrs={"class":"blogroll-item template-headline"}) # Health and politics section  
    for section in sections: # loop over the children sections
      try:
        link= section.h4.a # get the links under h4 from each section 
        sec_list.append(link["href"])
      except:
        pass
    
    return sec_list
  
def getNewsLinkUnderCategory(ctgry_link):
  """Returns the list of links under a category.
     ctgry_link: is a category link"""

  ctgry_soup= getSoup(ctgry_link) # make soup for a category
  news_list=[] # place holder to list all the news link under a category    

  try: 
      #find links under local news                          
      blogroll= ctgry_soup.find_all("div", attrs={"class": "embed-item embed-list blogroll-item"})
      for blog in blogroll:
        for link in  blog.find_all("a"):
          news_list.append(link.get("href"))
  except: 
      pass

  try: # to get links under Health and Politics 
    news_link=ctgry_soup.find("section", attrs={"class": "blogroll-item template-catalog"})
    for news in news_link.find_all("a"):
      news_list.append(news.get("href")) 
  except:
    pass

  return news_list

# %%
soup= getSoup("https://denver.cbslocal.com/category/news/")
getCategoryLink(soup)
# Out:
# ['https://denver.cbslocal.com/category/news/local/',
#  'http://denver.cbslocal.com/category/news/health/',
#  'http://denver.cbslocal.com/category/news/politics/']

# %% [markdown]
# ### Collect the data

# %%
def getNewsInfo(news_link):
    ''' Returns a dictionary containing infomation about the news such as headline, content and published data.
        news_link: the link from which the information is collected'''
    
    Url = news_link  
    Source = "CBS_Denver"  # the same for all links obtained from Denver CBS local 
   
    news_soup= getSoup(news_link) # make a soup 
    
    # Get Headline 
    #==============================
    try:  # try if title can be found  
        Headline= news_soup.find("h1",attrs={"class":"title"}).string # get the title .append(title)
    except:
        Headline="NA"    
    
   #Get Published Date and Time
    #=================================
    try:
        PublishedDateTime= news_soup.find("time",attrs={"class":"post-date"}).string  # get the date      
    except:
        PublishedDateTime= "NA"
 
          
    # Get Content 
    #===================================
    
    text=[] #placeholder to collect contents from multiple paragraphs
    try:   
        cont= news_soup.find("div",attrs={"class":"main-story-wrapper"})
        for c in cont.find_all("p"): # loop over each paragraph
            #get the text in each paragraph and append them
            text.append(c.get_text(separator=" ", strip=True).replace("\xa0", " ")) 

        Content=" ".join(text) # concatnate the paragraphs to make a single string 

    except:
        Content="NA"
           
    # collect  all the data as dictionay 
    data= {"Source": Source, 'Url': Url, 'PublishedDateTime': PublishedDateTime, 'Headline': Headline, 'Content': Content}
        
        # gather all companies info 
    return data

# %%
url= "http://denver.cbslocal.com/category/news/" # the page we are going to scrap
category= getCategoryLink(getSoup(url))  #get list of category links
all_data=[] # place holder to collect all the data 

# collect data from the categories
for ctgry in category:  
    links= getNewsLinkUnderCategory(ctgry)
    for link in links:
        all_data.append(getNewsInfo(link))

data= pd.DataFrame(all_data) # make a dataframe

# %%
print(data.shape)
data.head()
# Out:
# (42, 5)
#        Source                                                Url  \
# 0  CBS_Denver  https://denver.cbslocal.com/2022/04/28/these-w...
# 1  CBS_Denver  https://denver.cbslocal.com/2022/04/28/severe-...
# 2  CBS_Denver  https://denver.cbslocal.com/2022/04/28/paul-jo...
# 3  CBS_Denver  https://denver.cbslocal.com/2022/04/28/trahavo...
# 4  CBS_Denver  https://denver.cbslocal.com/2022/04/28/basebal...
#
#             PublishedDateTime  \
# 0   April 28, 2022 at 1:21 pm
# 1  April 28, 2022 at 12:24 pm
# 2  April 28, 2022 at 12:22 pm
# 3  April 28, 2022 at 11:30 am
# 4  April 28, 2022 at 10:36 am
#
#                                             Headline  \
# 0  Film Created At Cañon City Prison Humanizes Li...
# 1  Severe Drought In Colorado Jumps 15% In One We...
# 2  Jury Awards Nearly $9M To Families Who Accused...
# 3  Trahavonie Smith Arrested, Charged With Killin...
# 4  Highly Publicized Efforts To Repair Kennedy Hi...
#
#                                              Content
# 0  (CBS4) – A new film goes inside Colorado’s old...
# 1  DENVER (CBS4) – Drought in Colorado has been w...
# 2  (CBS4) – A jury has awarded nearly $9 million ...
# 3  (CBS4) – Denver police have arrested a man sus...
# 4  DENVER (CBS4) – A pitch to renovate the baseba...

# %% [markdown]
# ### Add more features

# %%
# run this command for every first excecution of the notebook
! python -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 18.4 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.6)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.21.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.64.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy.lang.en import English
import glob
import os
# !pip install googletrans
from googletrans import Translator
# Out:
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.7 MB/s
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Collecting hstspreload
#   Downloading hstspreload-2021.12.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 30.6 MB/s
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2.10)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 871 kB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2021.10.8)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.0 MB/s
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.1 MB/s
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15735 sha256=93e3374a1530480179de2049f9b77beb944b7024e0dc1c7fc8e5d368a5f04ae4
#   Stored in directory: /root/.cache/pip/wheels/20/da/eb/a54579056f265eede0417df537dd56d3df5b9eb2b25df0003d
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.12.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.2.0

# %%
def language_detect(data):
    trans = Translator()
    #print(trans.translate(data).text)
    try:
      a = trans.detect(data).lang
      #b= trans.translate(data, dest='en').text
    except:
      a= 'Unknown'
      #b= 'Translation Failed'

    return a

def language_translate(data):
    trans = Translator()
    #print(trans.translate(data).text)
    try:
      #a = trans.detect(data).lang
      b= trans.translate(data, dest='en').text
    except:
      #a= 'Unknown'
      b= 'Translation Failed'
    
    return b

def key_search(data, key):
  #print(data)
    if data.lower().find(key.lower()) <0:
      return 0
    else:
      return 1

def keyword_scores(data, keys):
    res = {}
    try:
      for key in keys:
        l = keys[key]
        #print(l)
        res[key] = sum(list( map( lambda x: key_search(data, x), l)))
    except:
      res[key] = 0

    return res

# %%
import json, requests, urllib, io

#user='my_github_username'
#pao='my_pao'


github_session = requests.Session()
#github_session.auth = (user, pao)

# providing raw url to download csv from github
csv_url = 'https://raw.githubusercontent.com/AR-github-AWS/testrepo/main/Keywords%20for%20Data%20Science.csv?token=GHSAT0AAAAAABTJTADX3DUWZIYFQ3PFQF34YSZYMOA'

download = github_session.get(csv_url).content
downloaded_csv = pd.read_csv(io.StringIO(download.decode('utf-8')), error_bad_lines=False)
df_keywords = downloaded_csv
df_keywords = df_keywords.astype('str').replace('nan')
keywords = df_keywords.to_dict('LIST')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
def GetFacetCols(dataframe,ColumnName):
    nlp = spacy.load("en_core_web_sm")
    OrgFacet=[]
    PersonFacet=[]
    LocationFacet=[]
    MoneyFacet = []
    LanguageFacet = []
    DateFacet = []
    #for i in range(len(dataframe)):
    for row in dataframe[ColumnName]:
        
        #data=dataframe[ColumnName][i]
        content = nlp(str(row))
        Org=[]
        Person=[]
        Location=[]
        Money = []
        Language = []
        Date = []
        
        try:
            
            for ent in content.ents:  # loop over the entities 
                if(ent.label_ == "ORG"):
                    if ent.text not in Org:
                        Org.append(ent.text)
                if(ent.label_ == "PERSON"):
                    if ent.text not in Person:
                        Person.append(ent.text)
                if(ent.label_ == "GPE"):
                    if ent.text not in Location:
                        Location.append(ent.text)
                if(ent.label_ == "MONEY"):
                    if ent.text not in Money:
                        Money.append(ent.text)
                if(ent.label_ == "LANGUAGE"):
                    if ent.text not in Language:
                        Language.append(ent.text)
                if(ent.label_ == "DATE"):
                    if ent.text not in Date:
                        Date.append(ent.text)
                        
        except:
            pass
        
        finally:
            OrgFacet.append(Org)
            PersonFacet.append(Person)
            LocationFacet.append(Location)
            MoneyFacet.append(Money)
            LanguageFacet.append(Language)
            DateFacet.append(Date)
            
                        
        
    dataframe['keyword score'] = list(map( lambda x: sum(keyword_scores(x, keywords).values()), dataframe[ColumnName]))
    dataframe['LanguageFacet'] = list( map( language_detect, dataframe[ColumnName]))
    dataframe['Translated Content'] = list( map( language_translate, dataframe[ColumnName]))
    dataframe['GeoFacet']=LocationFacet
    dataframe['OrgFacet']=OrgFacet
    dataframe['PeopleFacet']=PersonFacet
    dataframe['MoneyFacet'] = MoneyFacet
    dataframe['DateFacet'] = DateFacet
    
    return dataframe

# %%
GetFacetCols(data, 'Content')
# adding empty columns to the data frame
data["Threat"] = " "
data["Useful"] = " "
data["Comment"] = " "

# %% [markdown]
# ###Data is here

# %%
data
# Out:
#         Source                                                Url  \
# 0   CBS_Denver  https://denver.cbslocal.com/2022/04/28/these-w...
# 1   CBS_Denver  https://denver.cbslocal.com/2022/04/28/severe-...
# 2   CBS_Denver  https://denver.cbslocal.com/2022/04/28/paul-jo...
# 3   CBS_Denver  https://denver.cbslocal.com/2022/04/28/trahavo...
# 4   CBS_Denver  https://denver.cbslocal.com/2022/04/28/basebal...
# 5   CBS_Denver  https://denver.cbslocal.com/2022/04/28/making-...
# 6   CBS_Denver  https://denver.cbslocal.com/2022/04/28/young-m...
# 7   CBS_Denver  https://denver.cbslocal.com/2022/04/28/addicti...
# 8   CBS_Denver  https://denver.cbslocal.com/2022/04/28/larimer...
# 9   CBS_Denver  https://denver.cbslocal.com/2022/04/28/6th-ave...
# 10  CBS_Denver  https://denver.cbslocal.com/2022/04/28/lora-th...
# 11  CBS_Denver  https://denver.cbslocal.com/2022/04/28/denver-...
# 12  CBS_Denver  https://denver.cbslocal.com/2022/04/27/matthew...
# 13  CBS_Denver  https://denver.cbslocal.com/2022/04/27/colorad...
# 14  CBS_Denver  https://denver.cbslocal.com/2022/04/27/future-...
# 15  CBS_Denver  https://denver.cbslocal.com/2022/04/27/summit-...
# 16  CBS_Denver  https://denver.cbslocal.com/2022/04/26/red-roc...
# 17  CBS_Denver  https://denver.cbslocal.com/2022/04/26/itchy-e...
# 18  CBS_Denver  https://denver.cbslocal.com/2022/04/26/colorad...
# 19  CBS_Denver  https://denver.cbslocal.com/2022/04/23/air-qua...
# 20  CBS_Denver  https://denver.cbslocal.com/2022/04/22/viva-va...
# 21  CBS_Denver  https://denver.cbslocal.com/2022/04/22/covid-o...
# 22  CBS_Denver  https://denver.cbslocal.com/2022/04/21/covid-c...
# 23  CBS_Denver  https://denver.cbslocal.com/2022/04/21/air-qua...
# 24  CBS_Denver  https://denver.cbslocal.com/2022/04/21/colorad...
# 25  CBS_Denver  https://denver.cbslocal.com/2022/04/20/covid-o...
# 26  CBS_Denver  https://denver.cbslocal.com/2022/04/20/dave-hn...
# 27  CBS_Denver  https://denver.cbslocal.com/2022/04/20/autism-...
# 28  CBS_Denver  https://denver.cbslocal.com/2022/04/19/robert-...
# 29  CBS_Denver  https://denver.cbslocal.com/2022/04/19/polis-s...
# 30  CBS_Denver  https://denver.cbslocal.com/2022/04/28/lora-th...
# 31  CBS_Denver  https://denver.cbslocal.com/2022/04/27/colorad...
# 32  CBS_Denver  https://denver.cbslocal.com/2022/04/26/fentany...
# 33  CBS_Denver  https://denver.cbslocal.com/2022/04/26/right-r...
# 34  CBS_Denver  https://denver.cbslocal.com/2022/04/25/governo...
# 35  CBS_Denver  https://denver.cbslocal.com/2022/04/25/colorad...
# 36  CBS_Denver  https://denver.cbslocal.com/2022/04/25/univers...
# 37  CBS_Denver  https://denver.cbslocal.com/2022/04/22/fentany...
# 38  CBS_Denver  https://denver.cbslocal.com/2022/04/22/union-b...
# 39  CBS_Denver  https://denver.cbslocal.com/2022/04/22/denver-...
# 40  CBS_Denver  https://denver.cbslocal.com/2022/04/21/bill-pr...
# 41  CBS_Denver  https://denver.cbslocal.com/2022/04/21/covid-c...
#
#              PublishedDateTime  \
# 0    April 28, 2022 at 1:21 pm
# 1   April 28, 2022 at 12:24 pm
# 2   April 28, 2022 at 12:22 pm
# 3   April 28, 2022 at 11:30 am
# 4   April 28, 2022 at 10:36 am
# 5   April 28, 2022 at 10:30 am
# 6   April 28, 2022 at 10:28 am
# 7    April 28, 2022 at 9:59 am
# 8    April 28, 2022 at 8:57 am
# 9    April 28, 2022 at 8:35 am
# 10   April 28, 2022 at 7:52 am
# 11   April 28, 2022 at 7:00 am
# 12  April 27, 2022 at 11:30 pm
# 13   April 27, 2022 at 7:50 pm
# 14   April 27, 2022 at 5:43 pm
# 15   April 27, 2022 at 4:50 pm
# 16   April 26, 2022 at 5:18 pm
# 17   April 26, 2022 at 4:02 pm
# 18   April 26, 2022 at 2:13 pm
# 19   April 23, 2022 at 2:46 pm
# 20  April 22, 2022 at 10:10 pm
# 21   April 22, 2022 at 4:08 pm
# 22   April 21, 2022 at 4:41 pm
# 23   April 21, 2022 at 4:12 pm
# 24   April 21, 2022 at 7:38 am
# 25   April 20, 2022 at 6:08 pm
# 26   April 20, 2022 at 2:01 pm
# 27   April 20, 2022 at 7:57 am
# 28   April 19, 2022 at 5:12 pm
# 29   April 19, 2022 at 4:06 pm
# 30   April 28, 2022 at 7:52 am
# 31   April 27, 2022 at 7:50 pm
# 32  April 26, 2022 at 11:17 pm
# 33   April 26, 2022 at 7:40 pm
# 34   April 25, 2022 at 9:01 pm
# 35   April 25, 2022 at 3:12 pm
# 36  April 25, 2022 at 12:55 pm
# 37   April 22, 2022 at 9:09 pm
# 38   April 22, 2022 at 5:10 pm
# 39   April 22, 2022 at 4:58 pm
# 40   April 21, 2022 at 8:23 pm
# 41   April 21, 2022 at 4:41 pm
#
#                                              Headline  \
# 0   Film Created At Cañon City Prison Humanizes Li...
# 1   Severe Drought In Colorado Jumps 15% In One We...
# 2   Jury Awards Nearly $9M To Families Who Accused...
# 3   Trahavonie Smith Arrested, Charged With Killin...
# 4   Highly Publicized Efforts To Repair Kennedy Hi...
# 5   Overcoming Inflation A Primary Focus For Color...
# 6   Young Colorado Motel Owner Pushes Through Pand...
# 7   Denver Health Preparing For Capacity Changes I...
# 8   Larimer Sheriff: Toddler Home With Family Afte...
# 9   Crash Backs Up Traffic On 6th Avenue West of I...
# 10  Douglas County Commissioner Calls Colleague A ...
# 11  Travel And Adventure Show Returns To Denver To...
# 12  Castle Rock Police Ask For Help In Locating Ma...
# 13  Thousands Of County Workers In Colorado Could ...
# 14  Future Leaders Winner Designs Signs, Gets Less...
# 15  Summit School District One Of The First To Dit...
# 16  Red Rock Pharmacy In Denver Suspended From Sta...
# 17  Itchy Eyes? Stuffy Nose? You’re Not Alone: Win...
# 18  Colorado Doctor: Cutting Out Alcohol And Tobac...
# 19  Denver, Aurora Rank 7th Worst In U.S. For Ozon...
# 20  ‘Viva La Vacuna’ Artist Wins Contest Motivatin...
# 21  COVID Cases On The Rise In Colorado, Omicron V...
# 22  Gov. Jared Polis, State Lawmakers Team Up To P...
# 23  Report: Denver Among Most Polluted Cities In U.S.
# 24  They’re Your Medical Records. So, Why Do You H...
# 25  ‘Not Going Away’: Colorado Doctor Warns That W...
# 26  Dr. Dave Hnida On End To Mask Mandates For Tra...
# 27  Coloradans On The Spectrum Work To Overcome Ch...
# 28  Parker Man Faces Federal Charges For Allegedly...
# 29  Polis Sends Letter To President Urging COVID V...
# 30  Douglas County Commissioner Calls Colleague A ...
# 31  Thousands Of County Workers In Colorado Could ...
# 32  Emotions Run High As Debate Over Fentanyl Bill...
# 33  Right To Repair Bill Passes Out Of Senate, Mov...
# 34  ‘No Reason The Government Should Sit On Your M...
# 35   Fentanyl Bill Passes Out Of Colorado House 43-22
# 36  Gov. Jared Polis Signs Universal Pre-K Bill In...
# 37  House Gives Initial Approval To Fentanyl Bill ...
# 38  Collective Bargaining Unit Bill Faces Criticis...
# 39  Porcupine, Turtle, Snake Among Denver Zoo Resi...
# 40  Bill Provides Millions Of Dollars For Under-In...
# 41  Gov. Jared Polis, State Lawmakers Team Up To P...
#
#                                               Content  keyword score  \
# 0   (CBS4) – A new film goes inside Colorado’s old...              0
# 1   DENVER (CBS4) – Drought in Colorado has been w...              0
# 2   (CBS4) – A jury has awarded nearly $9 million ...              0
# 3   (CBS4) – Denver police have arrested a man sus...              0
# 4   DENVER (CBS4) – A pitch to renovate the baseba...              0
# 5   DENVER (CBS4) – Inflation is not only hurting ...              0
# 6   SALIDA, Colo. (CBS4) – Anita Kudasik had grown...              0
# 7   (CBS4) – Every week Denver Health’s Center for...              0
# 8   WELLINGTON, Colo. (CBS4) — A young boy is back...              0
# 9   (CBS4) — A crash on 6th Avenue west of Interst...              0
# 10  DOUGLAS COUNTY, Colo. (CBS4) – For the second ...              0
# 11  DENVER (CBS4) – The Denver Travel and Adventur...              0
# 12  CASTLE ROCK, Colo. (CBS4) – Police in Castle R...              0
# 13  DENVER (CBS4) – Dozens of county commissioners...              0
# 14  RIFLE, Colo. (CBS4) – Every month during the s...              0
# 15  SUMMIT COUNTY, Colo. (CBS4) – For the Summit S...              0
# 16  By Danielle Chavira DENVER (CBS4) – The Colora...              0
# 17  DENVER (CBS4) – Spring is in the air and so is...              0
# 18  ENGLEWOOD, Colo. (CBS4) – We may wind down wit...              0
# 19  DENVER (CBS4) – The Front Range may be gasping...              0
# 20  DENVER (CBS4) – It’s a message that’s clear. (...              0
# 21  DENVER (CBS4) – COVID cases are on the rise ag...              0
# 22  DENVER (CBS4) – Gov. Jared Polis announced Thu...              0
# 23  DENVER (CBS4) – A new report shows that Colora...              0
# 24  DENVER (CBS4) – In the digital age, you would ...              0
# 25  DENVER (CBS4 ) –  The Justice Department has f...              0
# 26  DENVER (CBS4) – With subvariants of Omicron sp...              0
# 27  (CBS4) – The impact of COVID-19 on people with...              0
# 28  PARKER, Colo. (CBS4) – A Parker man is accused...              0
# 29  DENVER (CBS4) – Gov. Jared Polis wants the Whi...              0
# 30  DOUGLAS COUNTY, Colo. (CBS4) – For the second ...              0
# 31  DENVER (CBS4) – Dozens of county commissioners...              0
# 32  DENVER (CBS4) – Opponents of a bill addressing...              0
# 33  By Danielle Chavira DENVER (CBS4) – The Colora...              0
# 34  (CBS4) – Call it Christmas in July: Gov. Jared...              0
# 35  DENVER (CBS4) – The Colorado State Senate will...              0
# 36  DENVER (CBS4) – Gov. Jared Polis signed a bill...              0
# 37  DENVER (CBS4) – The state House has given init...              0
# 38  DENVER (CBS4) – Two Democratic state lawmakers...              0
# 39  DENVER (CBS4) – State lawmakers took a break f...              0
# 40  SUPERIOR, Colo. (CBS4) – Four months after the...              0
# 41  DENVER (CBS4) – Gov. Jared Polis announced Thu...              0
#
#    LanguageFacet  Translated Content  \
# 0        Unknown  Translation Failed
# 1        Unknown  Translation Failed
# 2        Unknown  Translation Failed
# 3        Unknown  Translation Failed
# 4        Unknown  Translation Failed
# 5        Unknown  Translation Failed
# 6        Unknown  Translation Failed
# 7        Unknown  Translation Failed
# 8        Unknown  Translation Failed
# 9        Unknown  Translation Failed
# 10       Unknown  Translation Failed
# 11       Unknown  Translation Failed
# 12       Unknown  Translation Failed
# 13       Unknown  Translation Failed
# 14       Unknown  Translation Failed
# 15       Unknown  Translation Failed
# 16       Unknown  Translation Failed
# 17       Unknown  Translation Failed
# 18       Unknown  Translation Failed
# 19       Unknown  Translation Failed
# 20       Unknown  Translation Failed
# 21       Unknown  Translation Failed
# 22       Unknown  Translation Failed
# 23       Unknown  Translation Failed
# 24       Unknown  Translation Failed
# 25       Unknown  Translation Failed
# 26       Unknown  Translation Failed
# 27       Unknown  Translation Failed
# 28       Unknown  Translation Failed
# 29       Unknown  Translation Failed
# 30       Unknown  Translation Failed
# 31       Unknown  Translation Failed
# 32       Unknown  Translation Failed
# 33       Unknown  Translation Failed
# 34       Unknown  Translation Failed
# 35       Unknown  Translation Failed
# 36       Unknown  Translation Failed
# 37       Unknown  Translation Failed
# 38       Unknown  Translation Failed
# 39       Unknown  Translation Failed
# 40       Unknown  Translation Failed
# 41       Unknown  Translation Failed
#
#                                              GeoFacet  \
# 0                              [Colorado, Cañon City]
# 1   [Colorado, Denver, Broomfield, Thornton, North...
# 2                                                  []
# 3                                            [Denver]
# 4                      [Denver, the Colorado Rockies]
# 5                  [Colorado, Denver, Johnston, U.S.]
# 6                             [SALIDA, Colo., Salida]
# 7                                                  []
# 8                                 [WELLINGTON, Colo.]
# 9                                                  []
# 10            [DOUGLAS COUNTY, Colo., Douglas County]
# 11                                                 []
# 12        [CASTLE ROCK, Colo., Castle Rock, Colorado]
# 13                         [Colorado, Fremont County]
# 14                              [RIFLE, Colo., Rifle]
# 15                     [SUMMIT COUNTY, Summit County]
# 16                                           [Denver]
# 17                                           [sneezy]
# 18                                            [Colo.]
# 19                        [Colorado, Denver, Boulder]
# 20       [Viva Mexico, Denver, Servicios, Coloradans]
# 21                                         [Colorado]
# 22                                  [Colorado, Polis]
# 23                           [Colorado, U.S., Denver]
# 24                                                 []
# 25                             [Colorado, Washington]
# 26                                             [U.S.]
# 27                                         [Colorado]
# 28  [PARKER, Colo., the United States, U.S., Washi...
# 29                                         [Colorado]
# 30            [DOUGLAS COUNTY, Colo., Douglas County]
# 31                         [Colorado, Fremont County]
# 32                       [Colorado, America, Boulder]
# 33                                                 []
# 34                                [Colorado, Ukraine]
# 35                                      [Weld County]
# 36                             [Coloradans, Colorado]
# 37                                                 []
# 38                            [Colorado, Weld County]
# 39                                                 []
# 40                  [SUPERIOR, Colo., Boulder County]
# 41                                  [Colorado, Polis]
#
#                                              OrgFacet  \
# 0   [CBS4, the Territorial Correctional Facility, ...
# 1              [CBS, Greeley, Highland Ranch, Arvada]
# 2                  [CBS4, Grand Junction, CBS) Jones]
# 3                                     [Denver Police]
# 4   [Major League Baseball, CBS, Denver Public Sch...
# 5   [BRL Group, CBS, CBS4, Kapitus, Fed, IRS, Kapi...
# 6   [CBS, Metropolitan State University of Denver,...
# 7   [Denver Health’s Center for Addiction Medicine...
# 8          [the Larimer County Sheriff Facebook post]
# 9                [CBS4, CBS, CDOT, Federal Boulevard]
# 10                                              [CBS]
# 11  [The Denver Travel, The Denver Travel & Advent...
# 12  [Castle Rock Police, CBS, Buchanan, white Dodg...
# 13                                      [CBS, Senate]
# 14  [CBS4, PDC Energy, CBS, Coal Ridge High School...
# 15                     [the Summit School Board, CBS]
# 16  [The Colorado Department of Public Health and ...
# 17                [CBS, National Jewish Health, CBS4]
# 18          [HPV, CDC, Sloot, Swedish Medical Center]
# 19  [The Front Range, the American Lung Associatio...
# 20  [CBS, Jefferson High School, Colorado Foundati...
# 21  [COVID, The Colorado Department of Public Heal...
# 22                                       [COVID, CBS]
# 23  [the American Lung Association, CBS, Grand Jun...
# 24  [CBS, Sky Ridge Medical Center, Humphrey, Park...
# 25  [The Justice Department, The Centers for Disea...
# 26  [Omicron, CBS4 Medical Editor, CBS, CDC, Hnida...
# 27  [CBS4, COVID, the Centers for Disease Control ...
# 28  [Parker, District Court, Co-Conspirator-1, Cas...
# 29                        [the White House, CBS, FDA]
# 30                                              [CBS]
# 31                                      [CBS, Senate]
# 32  [the Senate Judiciary Committee, CBS, the Colo...
# 33          [The Colorado Senate, House, CBS, Senate]
# 34                  [CBS, Polis, CBS4, House, McKean]
# 35  [The Colorado State Senate, the House of Repre...
# 36               [CBS, Department of Early Childhood]
# 37  [House, CBS, the House Alec Garnett, the Appro...
# 38                                              [CBS]
# 39                         [Capitol, CBS, Denver Zoo]
# 40  [the Marshall Fire, Trustee Neal Shah, CBS, St...
# 41                                       [COVID, CBS]
#
#                                           PeopleFacet  \
# 0   [Eric Davis, Dean Williams, Walls, Williams, C...
# 1                                 [Aurora, Jefferson]
# 2                  [Paul Jones, Jones, Floyd Elliott]
# 3                           [Trahavonie Smith, Smith]
# 4   [Ron Gallegos, John F. Kennedy High School, Ke...
# 5   [Lilliana Luna, Luna, Kelly Werthmann, Ben Joh...
# 6                   [Anita Kudasik, Kudasik, Kudaski]
# 7                     [Josh Blum, Blum, Brook Bender]
# 8                                              [LCSO]
# 9                                [Sheridan Boulevard]
# 10  [Commissioners Abe Laydon, George Teal, Lora T...
# 11  [Unicomm, John Golicz, Patricia Schultz, Peter...
# 12  [Matthew Buchanan, Paint Pony Circle, Elizabet...
# 13  [Steve Fenberg, Kevin Grantham, Grantham, Shau...
# 14     [Conner Harte, braille, Harte, Lauren Whitney]
# 15                              [Kate Hudnut, Hudnut]
# 16                          [Danielle Chavira DENVER]
# 17  [Julie Eckert, itchy throat, Eckert, Flavia Ho...
# 18              [Getty Images, Paul Van der, Van der]
# 19  [Fort Collins, Anthony Gerber, Leslie Paffe, G...
# 20  [Monserrat Diaz, Diaz, Latino, Riveter, Servic...
# 21                                   [Rachel Herlihy]
# 22                                      [Jared Polis]
# 23                                     [Fort Collins]
# 24  [Lesley Humphrey, Lorraine Parker, Lindsey Dau...
# 25               [Reggie Washington, Mekialaya White]
# 26                                [Dave Hnida, Getty]
# 27  [Jo Klein, Klein, Tori Mason, Firefly Autism, ...
# 28           [Robert Van Camp, Van Camp, Parker, UC1]
# 29                        [Jared Polis, Biden, Polis]
# 30  [Commissioners Abe Laydon, George Teal, Lora T...
# 31  [Steve Fenberg, Kevin Grantham, Grantham, Shau...
# 32  [Paul Quinn, Matt Riviera, Andrew, Stephen Riv...
# 33  [Danielle Chavira DENVER, Coloradans, Jared Po...
# 34  [Jared Polis, Shaun Boyd, Polis, Shaun, Colora...
# 35                                                 []
# 36                               [Jared Polis, Pre-K]
# 37  [Terri Carver, Leslie Herod, Garnett, Mike Lyn...
# 38                                      [Scott James]
# 39                                  [Bert Verscolani]
# 40  [Michaels, Shah, Steve Fenberg, Dylan Roberts,...
# 41                                      [Jared Polis]
#
#                                            MoneyFacet  \
# 0                                                  []
# 1                                                  []
# 2                   [nearly $9 million, $8.7 million]
# 3                                                  []
# 4                  [$5 million, thousands of dollars]
# 5                               [about $1,000, 2,300]
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                              [millions of dollars]
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                            [1,000]
# 15                 [hundreds of thousands of dollars]
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24  [thousands of dollars, 248, more than $1,000, ...
# 25                                                 []
# 26                                                 []
# 27                                                 []
# 28    [thousands of dollars, hundred-dollar, 100,000]
# 29                                                 []
# 30                              [millions of dollars]
# 31                                                 []
# 32                              [millions of dollars]
# 33                                                 []
# 34  [400, 800, between $4/gallon gas and 40-year h...
# 35                                                 []
# 36                                 [more than $4,000]
# 37                    [one gram, millions of dollars]
# 38                                                 []
# 39                                                 []
# 40  [$2 million, $150 million to $200 million, $15...
# 41                                                 []
#
#                                             DateFacet Threat Useful Comment
# 0   [last year, 150th year, today, 34 years, early...
# 1   [recent weeks, this April, This past week, Apr...
# 2                                   [the 1980s, 2019]
# 3                              [West 13th, Wednesday]
# 4   [About a year ago, 2021, about 3 years, 11-14 ...
# 5   [summer, every single day, about every day, 20...
# 6   [several years, 2018, the year, the past 10 ye...
# 7                                       [months long]
# 8                                          [Thursday]
# 9                                          [Thursday]
# 10                  [a year, Tuesday, years, decades]
# 11  [this weekend, the fifth year, This year, Apri...
# 12                             [Tuesday, 32, 3964372]
# 13                                    [election year]
# 14              [Every month, the school year, April]
# 15    [the last two years, the darkest months, years]
# 16  [between Jan. 15, 2021, April 1, 2022, 1-877-2...
# 17  [this time of year, April, season, the last tw...
# 18                               [two or three weeks]
# 19                      [18th, 2000, Year after year]
# 20                          [Friday, seven-day, July]
# 21                                 [the coming weeks]
# 22                     [Thursday, the last two years]
# 23                                                 []
# 24                                        [year-long]
# 25        [Wednesday, the age of 60, 5-11, this week]
# 26         [May 3, the summer, the next three months]
# 27  [72 year old, 4 years old, 18 months old, 71, ...
# 28                          [roughly a year, Tuesday]
# 29  [the third summer, April 19, 2022, seven-day, ...
# 30                  [a year, Tuesday, years, decades]
# 31                                    [election year]
# 32      [Tuesday, over 50 years, every day, Thursday]
# 33                               [earlier this month]
# 34  [July, the next few months, next year, this su...
# 35                           [Tuesday, Monday, 43-22]
# 36                          [Monday, next year, 2023]
# 37                              [Friday, three years]
# 38                           [the final days, Friday]
# 39                                   [Friday, annual]
# 40  [Four months, the next several months, the fin...
# 41                     [Thursday, the last two years]

# %%
######## Click the blue magic wand thing Somewhere around the above table, it is probably right above the hashtags at the beginning of this code cell

# %% [markdown]
# ### Future use please ignore
# #### Save the data

# %%
# storing at "output" dir
#date = datetime.now().strftime("%Y-%m-%d--%H-%M-%S")
#file_name = "CBSLocal_Denver_" +date+ ".csv"
#data.to_csv(file_name, index = False)

# Storing a copy for analysts in the "analysts" dir
#data.to_csv( "/dbfs/mnt/analysts/" + file_name, index = False)

# %%
# appendix, not important to the generate the above data
#def getCategoryLinkfrmMainPg(soup):
   # """Returns a list containing the links of news categories
    #   soup: is the soup of a webpage from which the links of the categories extracted.
    # """
    #sec_list= [] # placeholder for section link
    
    #cbsn_link= soup.find("div", attrs={"class":"logo-container"}).a["href"] # get the link for cbsn-denver
    #sec_list.append(cbsn_link)
    
    #sections= soup.find("section", attrs={"id": "column_block_33"}) # sections parent 
    #try:
      #for section in sections.children: # loop over the children sections
     #   link= section.h4.a # get the links under h4 from each section 
    #    if link: # if exist 
   #       sec_list.append(link["href"])
  #  except:
      #pass
    
    #return sec_list

# %%
#getCategoryLinkfrmMainPg(res)
