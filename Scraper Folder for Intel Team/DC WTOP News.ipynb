# %% [markdown]
# ### Scraping Crime under KRDO news
# The scrapper collectes data from WTOP crime news(https://wtop.com/local/crime/)

# %%
import requests                # to request the webpage
from bs4 import BeautifulSoup  # to make soup and pull data out of HTML
import urllib.robotparser      # to check the legitimacy to scrap the web
import json                    # to save the output as json file
import pandas as pd            # to  see saved data as dataframe 
from datetime import datetime  # to get the current datetime
#import IPython                 # to display the webpage

# %% [markdown]
# ### Permission to scrap

# %%
robotpars = urllib.robotparser.RobotFileParser()  #instantiate the RobotFileParser

#set the robots.txt url of cbs local news 
robotpars.set_url("https://wtop.com/robots.txt")
robotpars.read() # Reads the robots.txt 

# to check if useragent can fetch the url, true means fetching is possible. 
print("Can we fetch the website?", \
      robotpars.can_fetch("*", "https://wtop.com/"))
# Out:
# Can we fetch the website? False

# %% [markdown]
# ### Get the links

# %%
def getSoup(url):
    """make a soup for a webpage given its url""" 

    # request the webpage and get the text
    pagetext= requests.get(url).text
    #make a soup and use html parser for the content of the web page 
    soup= BeautifulSoup(pagetext, "html.parser")
    return soup
  
def getNewsLink(soup):
  """Returns a list containing the links of news article.
       soup: is the soup of a webpage from which the links will be extracted.
     """
  news_list=[] # place holder to collect all the links of the news article
  
  try:
    articles = soup.find_all("h3", attrs={"class": "post__template-title"})
    for artc in articles:
      link= artc.a["href"] # get the link for each news article
      news_list.append(link) 
  except:
    pass
  return news_list

# %%
soup =getSoup("https://wtop.com/local/crime/")
getNewsLink(soup)[:3]
# Out:
# ['https://wtop.com/prince-william-county/2022/05/reward-offered-photos-released-in-shooting-of-teen-girl-at-prince-william-co-carnival/',
#  'https://wtop.com/dc/2022/05/dc-bar-and-restaurant-loses-more-than-200k-in-cyber-crime/',
#  'https://wtop.com/virginia/2022/05/va-case-focusing-debate-on-constitutionality-of-geofence-warrant-ends-with-guilty-plea/']

# %% [markdown]
# ### Collect the data

# %%
def getNewsInfo(news_link):
    ''' Returns a dictionary containing infomation about the news such as headline, content and published data.
        news_link: the link from which the information is collected'''
    
    Url = news_link  
    Source = "Article_WTOP"  # the same for all links obtained from the main source 
   
    news_soup= getSoup(news_link) # make a soup 
    
    # Get Headline 
    #==============================
    try:  # try if title can be found  
        Headline= news_soup.find("h1",attrs={"class":"page__single--title schema-title"}).get_text() # get the title .append(title)
    except:
        Headline="NA"    
    
   #Get Published Date and Time
    #=================================
    try:
        PublishedDateTime= news_soup.find("p",attrs={"class":"article-post__date"}).string  # get the date      
    except:
        PublishedDateTime= "NA"
 
          
    # Get Content 
    #===================================
    
    text=[] #placeholder to collect contents from multiple paragraphs
    try:   
        cont= news_soup.find("div",attrs={"id":"Entry-content"})
        for c in cont.find_all("p"): # loop over each paragraph
            #get the text in each paragraph and append them
            text.append(c.get_text(separator=" ", strip=True).replace("\xa0", " ")) 

        Content=" ".join(text) # concatnate the paragraphs to make a single string 

    except:
        Content="NA"
           
    # collect  all the data as dictionay 
    data= {"Source": Source, 'Url': Url, 'PublishedDateTime': PublishedDateTime, 'Headline': Headline, 'Content': Content}
        
        # gather all companies info 
    return data

# %%
url= "https://wtop.com/local/crime/" # the page we are going to scrap
soup=getSoup(url)
news_url= getNewsLink(soup) #get list of category links
all_data=[] # place holder to collect all the data 
for link in news_url:
    all_data.append(getNewsInfo(link))
data= pd.DataFrame(all_data) # make a dataframe

# %%
data.head()
# Out:
#          Source                                                Url  \
# 0  Article_WTOP  https://wtop.com/prince-william-county/2022/05...
# 1  Article_WTOP  https://wtop.com/dc/2022/05/dc-bar-and-restaur...
# 2  Article_WTOP  https://wtop.com/virginia/2022/05/va-case-focu...
# 3  Article_WTOP  https://wtop.com/maryland/2022/05/maryland-upd...
# 4  Article_WTOP  https://wtop.com/dc/2022/05/dc-police-shoot-at...
#
#         PublishedDateTime                                           Headline  \
# 0   May 10, 2022, 1:48 PM  Reward offered, photos released in shooting of...
# 1  May 10, 2022, 11:43 AM  DC bar and restaurant loses more than $200K in...
# 2  May 10, 2022, 10:18 AM  Va. case focusing debate on constitutionality ...
# 3   May 10, 2022, 8:13 AM  Maryland updates stalking law, includes digita...
# 4   May 9, 2022, 11:06 PM  DC police shoot at 1 after routine traffic sto...
#
#                                              Content
# 0  A reward has been offered in the shooting of a...
# 1  A bar and restaurant in D.C. is still struggli...
# 2  After more than two years of litigation in sta...
# 3  Maryland has updated its stalking law to inclu...
# 4  A man is in custody following a routine traffi...

# %% [markdown]
# ### Add more features

# %%
# run this command for every first excecution of the notebook
! python -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 5.6 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.21.6)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.64.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.10.8)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy.lang.en import English
import glob
import os
# !pip install googletrans
from googletrans import Translator
# Out:
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 1.7 MB/s
# Collecting hstspreload
#   Downloading hstspreload-2021.12.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 10.5 MB/s
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2.10)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2021.10.8)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 764 kB/s
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.6 MB/s
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.9 MB/s
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15735 sha256=2879dc8e48d72d3cad5be73f919646642726408908857aab016e54dcb9299810
#   Stored in directory: /root/.cache/pip/wheels/20/da/eb/a54579056f265eede0417df537dd56d3df5b9eb2b25df0003d
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.12.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.2.0

# %%
def language_detect(data):
    trans = Translator()
    #print(trans.translate(data).text)
    try:
      a = trans.detect(data).lang
      #b= trans.translate(data, dest='en').text
    except:
      a= 'Unknown'
      #b= 'Translation Failed'

    return a

def language_translate(data):
    trans = Translator()
    #print(trans.translate(data).text)
    try:
      #a = trans.detect(data).lang
      b= trans.translate(data, dest='en').text
    except:
      #a= 'Unknown'
      b= 'Translation Failed'
    
    return b

def key_search(data, key):
  #print(data)
    if data.lower().find(key.lower()) <0:
      return 0
    else:
      return 1

def keyword_scores(data, keys):
    res = {}
    try:
      for key in keys:
        l = keys[key]
        #print(l)
        res[key] = sum(list( map( lambda x: key_search(data, x), l)))
    except:
      res[key] = 0

    return res

# %%
import json, requests, urllib, io

#user='my_github_username'
#pao='my_pao'


github_session = requests.Session()
#github_session.auth = (user, pao)

# providing raw url to download csv from github
csv_url = 'https://raw.githubusercontent.com/AR-github-AWS/testrepo/main/Keywords%20for%20Data%20Science.csv?token=GHSAT0AAAAAABTJTADX3DUWZIYFQ3PFQF34YSZYMOA'

download = github_session.get(csv_url).content
downloaded_csv = pd.read_csv(io.StringIO(download.decode('utf-8')), error_bad_lines=False)
df_keywords = downloaded_csv
df_keywords = df_keywords.astype('str').replace('nan')
keywords = df_keywords.to_dict('LIST')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
def GetFacetCols(dataframe,ColumnName):
    nlp = spacy.load("en_core_web_sm")
    OrgFacet=[]
    PersonFacet=[]
    LocationFacet=[]
    MoneyFacet = []
    LanguageFacet = []
    DateFacet = []
    #for i in range(len(dataframe)):
    for row in dataframe[ColumnName]:
        
        #data=dataframe[ColumnName][i]
        content = nlp(str(row))
        Org=[]
        Person=[]
        Location=[]
        Money = []
        Language = []
        Date = []
        
        try:
            
            for ent in content.ents:  # loop over the entities 
                if(ent.label_ == "ORG"):
                    if ent.text not in Org:
                        Org.append(ent.text)
                if(ent.label_ == "PERSON"):
                    if ent.text not in Person:
                        Person.append(ent.text)
                if(ent.label_ == "GPE"):
                    if ent.text not in Location:
                        Location.append(ent.text)
                if(ent.label_ == "MONEY"):
                    if ent.text not in Money:
                        Money.append(ent.text)
                if(ent.label_ == "LANGUAGE"):
                    if ent.text not in Language:
                        Language.append(ent.text)
                if(ent.label_ == "DATE"):
                    if ent.text not in Date:
                        Date.append(ent.text)
                        
        except:
            pass
        
        finally:
            OrgFacet.append(Org)
            PersonFacet.append(Person)
            LocationFacet.append(Location)
            MoneyFacet.append(Money)
            LanguageFacet.append(Language)
            DateFacet.append(Date)
            
                        
        
    dataframe['keyword score'] = list(map( lambda x: sum(keyword_scores(x, keywords).values()), dataframe[ColumnName]))
    dataframe['LanguageFacet'] = list( map( language_detect, dataframe[ColumnName]))
    dataframe['Translated Content'] = list( map( language_translate, dataframe[ColumnName]))
    dataframe['GeoFacet']=LocationFacet
    dataframe['OrgFacet']=OrgFacet
    dataframe['PeopleFacet']=PersonFacet
    dataframe['MoneyFacet'] = MoneyFacet
    dataframe['DateFacet'] = DateFacet
    
    return dataframe

# %%
GetFacetCols(data, 'Content')
# adding empty columns to the data frame
data["Threat"] = " "
data["Useful"] = " "
data["Comment"] = " "

# %% [markdown]
# ### Data is here

# %%
data
# Out:
#           Source                                                Url  \
# 0   Article_WTOP  https://wtop.com/prince-william-county/2022/05...
# 1   Article_WTOP  https://wtop.com/dc/2022/05/dc-bar-and-restaur...
# 2   Article_WTOP  https://wtop.com/virginia/2022/05/va-case-focu...
# 3   Article_WTOP  https://wtop.com/maryland/2022/05/maryland-upd...
# 4   Article_WTOP  https://wtop.com/dc/2022/05/dc-police-shoot-at...
# 5   Article_WTOP  https://wtop.com/loudoun-county/2022/05/va-ag-...
# 6   Article_WTOP  https://wtop.com/dc/2022/05/man-injured-in-nor...
# 7   Article_WTOP  https://wtop.com/fairfax-county/2022/05/northe...
# 8   Article_WTOP  https://wtop.com/prince-william-county/2022/05...
# 9   Article_WTOP  https://wtop.com/crime/2022/05/silver-spring-d...
# 10  Article_WTOP  https://wtop.com/charles-county/2022/05/md-air...
# 11  Article_WTOP  https://wtop.com/virginia/2022/05/ex-official-...
# 12  Article_WTOP  https://wtop.com/dc/2022/05/man-charged-with-1...
# 13  Article_WTOP  https://wtop.com/maryland/2022/05/man-pleads-g...
# 14  Article_WTOP  https://wtop.com/maryland/2022/05/maryland-man...
# 15  Article_WTOP  https://wtop.com/alexandria/2022/05/five-men-s...
# 16  Article_WTOP  https://wtop.com/prince-georges-county/2022/05...
# 17  Article_WTOP  https://wtop.com/local/2022/05/dc-police-offic...
# 18  Article_WTOP  https://wtop.com/prince-georges-county/2022/05...
# 19  Article_WTOP  https://wtop.com/prince-georges-county/2022/05...
# 20  Article_WTOP  https://wtop.com/maryland/2022/05/police-off-d...
# 21  Article_WTOP  https://wtop.com/montgomery-county/2022/05/thr...
# 22  Article_WTOP  https://wtop.com/montgomery-county/2022/05/mon...
# 23  Article_WTOP  https://wtop.com/virginia/2022/05/virginia-man...
#
#          PublishedDateTime                                           Headline  \
# 0    May 10, 2022, 1:48 PM  Reward offered, photos released in shooting of...
# 1   May 10, 2022, 11:43 AM  DC bar and restaurant loses more than $200K in...
# 2   May 10, 2022, 10:18 AM  Va. case focusing debate on constitutionality ...
# 3    May 10, 2022, 8:13 AM  Maryland updates stalking law, includes digita...
# 4    May 9, 2022, 11:06 PM  DC police shoot at 1 after routine traffic sto...
# 5    May 9, 2022, 12:16 AM  Va. AG office denies LGBTQ student records sub...
# 6    May 8, 2022, 11:30 PM                  Man injured in Northwest DC crash
# 7     May 8, 2022, 6:29 PM  Northern Va. gang members convicted of murder,...
# 8     May 8, 2022, 4:41 PM  Dumfries man killed in early morning Gainesvil...
# 9    May 8, 2022, 10:36 AM  Silver Spring dentist pleads guilty to mail an...
# 10    May 7, 2022, 9:48 PM  Md. Air Force lieutenant sentenced to 11 yrs i...
# 11    May 7, 2022, 5:43 PM  Ex-official pleads guilty to attempted witness...
# 12    May 7, 2022, 5:43 PM  Man charged with 1st-degree murder for shootin...
# 13    May 7, 2022, 2:54 PM  Man pleads guilty to stealing $1.8M from Maryl...
# 14   May 7, 2022, 12:14 PM  Maryland man sentenced to prison for producing...
# 15    May 7, 2022, 8:52 AM  Five men steal more than $20K of eyeglasses in...
# 16    May 7, 2022, 1:41 AM                   1 killed in Forestville shooting
# 17   May 6, 2022, 10:22 PM  DC police officer arrested after fight in Prin...
# 18    May 6, 2022, 8:57 PM  Video shows vehicles linked to Prince George’s...
# 19    May 6, 2022, 5:58 PM  Prince George’s Co. police seek suspect after ...
# 20    May 6, 2022, 5:19 PM  Police: Off-duty officer involved in shooting ...
# 21    May 6, 2022, 3:57 PM  3 teens remain held in adult jails after Germa...
# 22   May 6, 2022, 11:32 AM  Montgomery Co. man pleads guilty to fentanyl d...
# 23   May 6, 2022, 10:53 AM  Virginia man charged with dealing illegal mach...
#
#                                               Content  keyword score  \
# 0   A reward has been offered in the shooting of a...              0
# 1   A bar and restaurant in D.C. is still struggli...              0
# 2   After more than two years of litigation in sta...              0
# 3   Maryland has updated its stalking law to inclu...              0
# 4   A man is in custody following a routine traffi...              0
# 5   Attorney General Jason Miyares has denied clai...              0
# 6   D.C. police say that a man is in the hospital ...              0
# 7   Three members of Fairfax County’s “Reccless Ti...              0
# 8   A young man was shot and killed early Sunday m...              0
# 9   A dentist from Silver Spring, Maryland, pleade...              0
# 10  Editor’s Note: This article contains discussio...              0
# 11  CHARLOTTESVILLE, Va. (AP) — A federal prosecut...              0
# 12  The man who police say shot and killed a D.C. ...              0
# 13  BALTIMORE (AP) — A man has pleaded guilty to t...              0
# 14  BALTIMORE (AP) — A federal judge has sentenced...              0
# 15  Fairfax County Police are looking for four men...              0
# 16  A man was killed after a shooting in Prince Ge...              0
# 17  A D.C. police officer was arrested Friday morn...              0
# 18  Police in Prince George’s County, Maryland, re...              0
# 19  Prince George’s County, Maryland, police are s...              0
# 20  PARKVILLE, Md. (AP) — Two people were injured ...              0
# 21  Three teenagers facing murder charges after th...              0
# 22  A Montgomery County, Maryland, man has plead g...              0
# 23  NORFOLK, Va. (AP) — A prosecutor says a federa...              0
#
#    LanguageFacet  Translated Content  \
# 0        Unknown  Translation Failed
# 1        Unknown  Translation Failed
# 2        Unknown  Translation Failed
# 3        Unknown  Translation Failed
# 4        Unknown  Translation Failed
# 5        Unknown  Translation Failed
# 6        Unknown  Translation Failed
# 7        Unknown  Translation Failed
# 8        Unknown  Translation Failed
# 9        Unknown  Translation Failed
# 10       Unknown  Translation Failed
# 11       Unknown  Translation Failed
# 12       Unknown  Translation Failed
# 13       Unknown  Translation Failed
# 14       Unknown  Translation Failed
# 15       Unknown  Translation Failed
# 16       Unknown  Translation Failed
# 17       Unknown  Translation Failed
# 18       Unknown  Translation Failed
# 19       Unknown  Translation Failed
# 20       Unknown  Translation Failed
# 21       Unknown  Translation Failed
# 22       Unknown  Translation Failed
# 23       Unknown  Translation Failed
#
#                                              GeoFacet  \
# 0   [Prince William County, Virginia, Woodbridge, ...
# 1                                              [D.C.]
# 2           [Virginia, Chesterfield County, Richmond]
# 3                     [Maryland, Anne Arundel County]
# 4                              [Northeast D.C., D.C.]
# 5    [Loudoun County LGBTQ, Loudoun County, Virginia]
# 6                                   [D.C., Northwest]
# 7   [Fairfax County, Richmond, California, Centrev...
# 8      [Gainesville, Virginia, Prince William County]
# 9                     [Silver Spring, Maryland, D.C.]
# 10  [Waldorf, Maryland, U.S., New York, Pocomoke C...
# 11                             [Va., Virginia county]
# 12                                  [D.C., Southeast]
# 13                        [Maryland, U.S., Salisbury]
# 14                     [Maryland, U.S., Elkton, Kyte]
# 15                             [Alexandria, Virginia]
# 16  [Prince George’s County, Maryland, Forestville...
# 17  [D.C., Prince George’s County, Maryland, Belts...
# 18  [Prince George’s County, Maryland, District He...
# 19  [Prince George’s County, Maryland, Bowie, Wash...
# 20  [Md., Maryland, Baltimore County, Parkville, M...
# 21      [Frederick, Maryland, Germantown, Kensington]
# 22  [Montgomery County, Maryland, Enitan, Germanto...
# 23     [Va., Virginia, U.S., Virginia Beach, Adamiak]
#
#                                              OrgFacet  \
# 0   [Gar-Field High School, the Bureau of Alcohol,...
# 1                         [BB&T, SunTrust, WTOP, FBI]
# 2              [Okello Chatrie, Google, Lauck, Court]
# 3                                             [House]
# 4                                            [Contee]
# 5   [FERPA, WTOP, Stone Bridge High School, Broad ...
# 6                                             [Chevy]
# 7   [Reccless Tiger, Reccless Tigers, the Reccless...
# 8                      [Prince William County Police]
# 9   [the Department of Justice, Medicaid, Buford, ...
# 10  [The National Sexual Assault Hotline, U.S. Air...
# 11  [AP, The U.S. Department of Justice, The Assoc...
# 12  [the Capital Area Regional Fugitive Task Force...
# 13  [AP, Shore Appliance Connection, The Associate...
# 14  [AP, the Elkton Police Department, The Associa...
# 15  [Fairfax County Police, Toyota, the Criminal I...
# 16                              [Donnell Place, WTOP]
# 17                                                 []
# 18                              [PGPDNEWS, @PGPDNews]
# 19                                    [Crime Solvers]
# 20                         [AP, The Associated Press]
# 21      [the Montgomery County Correctional Facility]
# 22                                       [Anton Agbi]
# 23  [NORFOLK, AP, the Bureau of Alcohol, Tobacco, ...
#
#                                           PeopleFacet  \
# 0                                                  []
# 1   [Johnny Pistolas, Adams Morgan, Jonathan Askar...
# 2                      [Chatrie, Hannah Lauck, Lauck]
# 3                       [Sandy Bartlett, Larry Hogan]
# 4                                     [Robert Contee]
# 5   [Jason Miyares, Equality Loudoun, Miyares, Spo...
# 6                                                  []
# 7   [Brandon White, White, Peter Le, Young Yoo, Jo...
# 8                    [Michael Arthur, Police, Arthur]
# 9                              [Edward T. Buford III]
# 10  [Jason Ort, Theodore D. Chuang, Ort, Erek Barron]
# 11            [Larry Vernon Snow, Bryant Austin Snow]
# 12  [Jarrell David Harris, Sedrick Miller, William...
# 13           [Erek Barron, Duane G. Larmore, Larmore]
# 14           [Erek Barron, Johnny William Kyte, Kyte]
# 15                               [Frederick Chambers]
# 16                                                 []
# 17                          [Dennis Sfoglia, Sfoglia]
# 18  [https://t.co/cdc9uAe67r pic.twitter.com/HZZS1...
# 19                     [Javon Washington, Glenn Dale]
# 20                                                 []
# 21                                       [Taon Cline]
# 22                   [Mouroukeji Agbi, Paul W. Grimm]
# 23   [Jessica D. Aber, Patrick Tate Adamiak, Adamiak]
#
#                                MoneyFacet  \
# 0                                 [6,000]
# 1   [nearly $500,000, more than $200,000]
# 2                                      []
# 3                                 [5,000]
# 4                                      []
# 5                                      []
# 6                                      []
# 7                   [thousands of pounds]
# 8                                      []
# 9                [more than $1.2 million]
# 10                                     []
# 11                                     []
# 12                                     []
# 13               [more than $1.8 million]
# 14                                     []
# 15                         [over $20,000]
# 16                                     []
# 17                                     []
# 18                                     []
# 19                        [up to $25,000]
# 20                                     []
# 21                                     []
# 22                                     []
# 23                                     []
#
#                                             DateFacet Threat Useful Comment
# 0                     [last month, Tuesday, April 15]
# 1                                   [months, Dec. 31]
# 2   [more than two years, Monday, Aug. 2, March, t...
# 3          [Oct. 1, 2022, April 21, 2022, five years]
# 4                                     [1700, Tuesday]
# 5   [Saturday, May 4, May 10, May of 2021, October...
# 6                                                  []
# 7   [2019, January 2019, two months, 2011, Sept. 9...
# 8                                                  []
# 9   [Wednesday, 70, Between January 2013, May 2018...
# 10  [1st, 11 years, 15 years, Thursday, between Se...
# 11                                           [Friday]
# 12  [March, 27, Friday, 42 year-old, five-year-old...
# 13           [Friday, mid-September 2016, March 2020]
# 14                 [20 years, Friday, Sept. 10, 2020]
# 15  [April 19, May 5, between 17 and 23 years old,...
# 16                                           [Friday]
# 17                                    [Friday, 10600]
# 18                               [May 6, 2022, 4, 14]
# 19                 [Thursday, 33, 301-516-2512, 8477]
# 20                                 [Thursday, Friday]
# 21  [last month, Friday, the days, a week, later t...
# 22  [Aug. 2020, 38, Thursday, Aug. 10, 2020, That ...
# 23              [Thursday, between October and April]

# %% [markdown]
# ### Ignore

# %%
# storing at "output" dir
#date = datetime.now().strftime("%Y-%m-%d--%H-%M-%S")
#file_name = "Article_WTOP_" +date+ ".csv"
#data.to_csv( "/dbfs/mnt/dboutput/" + file_name, index = False)
#data.to_csv(file_name, index = False)
# Storing a copy for analysts in the "analysts" dir
#data.to_csv( "/dbfs/mnt/analysts/" + file_name, index = False)
